# %% [markdown]
# # PANDAS ASSIGNMENT - ROHAN BIRADAR

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ## A. Hitters Dataset

# %%
path1 = r"C:\Users\ASUS\Documents\basic_pythonfiles\project 1\hitters.csv"
path1
# Out:
# 'C:\\Users\\ASUS\\Documents\\basic_pythonfiles\\project 1\\hitters.csv'

# %%
import pandas as pd
df = pd.read_csv(path1)

# %%
df
# Out:
#                  Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0       Andy Allanson    293    66      1    30   29     14      1     293
# 1          Alan Ashby    315    81      7    24   38     39     14    3449
# 2         Alvin Davis    479   130     18    66   72     76      3    1624
# 3        Andre Dawson    496   141     20    65   78     37     11    5628
# 4    Andres Galarraga    321    87     10    39   42     30      2     396
# ..                ...    ...   ...    ...   ...  ...    ...    ...     ...
# 317      Willie McGee    497   127      7    65   48     37      5    2703
# 318   Willie Randolph    492   136      5    76   50     94     12    5511
# 319    Wayne Tolleson    475   126      3    61   43     52      6    1700
# 320     Willie Upshaw    573   144      9    85   60     78      8    3198
# 321     Willie Wilson    631   170      9    77   44     31     11    4908
#
# ...

# %%
df.head()
# Out:
#                Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0     Andy Allanson    293    66      1    30   29     14      1     293
# 1        Alan Ashby    315    81      7    24   38     39     14    3449
# 2       Alvin Davis    479   130     18    66   72     76      3    1624
# 3      Andre Dawson    496   141     20    65   78     37     11    5628
# 4  Andres Galarraga    321    87     10    39   42     30      2     396
#
#    CHits  ...  CRuns  CRBI  CWalks  League Division PutOuts  Assists  Errors  \
# 0     66  ...     30    29      14       A        E     446       33      20
# 1    835  ...    321   414     375       N        W     632       43      10
# 2    457  ...    224   266     263       A        W     880       82      14
# 3   1575  ...    828   838     354       N        E     200       11       3
# 4    101  ...     48    46      33       N        E     805       40       4
#
#    Salary  NewLeague
# 0     NaN          A
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       322 non-null    object
#  1   AtBat      322 non-null    int64
#  2   Hits       322 non-null    int64
#  3   HmRun      322 non-null    int64
#  4   Runs       322 non-null    int64
#  5   RBI        322 non-null    int64
#  6   Walks      322 non-null    int64
#  7   Years      322 non-null    int64
#  8   CAtBat     322 non-null    int64
#  9   CHits      322 non-null    int64
#  10  CHmRun     322 non-null    int64
#  11  CRuns      322 non-null    int64
#  12  CRBI       322 non-null    int64
#  13  CWalks     322 non-null    int64
#  14  League     322 non-null    object
#  15  Division   322 non-null    object
#  16  PutOuts    322 non-null    int64
#  17  Assists    322 non-null    int64
#  18  Errors     322 non-null    int64
#  19  Salary     263 non-null    float64
# ...

# %% [markdown]
# ### Setting to see complete DATAFRAME

# %%
pd.set_option("display.max_rows",350)
pd.set_option("display.max_columns",30)

# %%
df.head()
# Out:
#                Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0     Andy Allanson    293    66      1    30   29     14      1     293
# 1        Alan Ashby    315    81      7    24   38     39     14    3449
# 2       Alvin Davis    479   130     18    66   72     76      3    1624
# 3      Andre Dawson    496   141     20    65   78     37     11    5628
# 4  Andres Galarraga    321    87     10    39   42     30      2     396
#
#    CHits  CHmRun  CRuns  CRBI  CWalks League Division  PutOuts  Assists  \
# 0     66       1     30    29      14      A        E      446       33
# 1    835      69    321   414     375      N        W      632       43
# 2    457      63    224   266     263      A        W      880       82
# 3   1575     225    828   838     354      N        E      200       11
# 4    101      12     48    46      33      N        E      805       40
#
#    Errors  Salary NewLeague
# 0      20     NaN         A
# 1      10   475.0         N
# ...

# %% [markdown]
# ### 1. Find out no of missing values in each column

# %%
m = df.isna().sum()
m
# Out:
# Name          0
# AtBat         0
# Hits          0
# HmRun         0
# Runs          0
# RBI           0
# Walks         0
# Years         0
# CAtBat        0
# CHits         0
# CHmRun        0
# CRuns         0
# CRBI          0
# CWalks        0
# League        0
# Division      0
# PutOuts       0
# Assists       0
# Errors        0
# Salary       59
# NewLeague     0
# dtype: int64

# %%
m[m>0]
# Out:
# Salary    59
# dtype: int64

# %% [markdown]
# ### 2. Find of people who have batted for more than 400 matches

# %%
df.query("CAtBat > 400")[["Name","CAtBat"]]
# Out:
#                   Name  CAtBat
# 1           Alan Ashby    3449
# 2          Alvin Davis    1624
# 3         Andre Dawson    5628
# 5      Alfredo Griffin    4408
# 7      Argenis Salazar     509
# 9       Andre Thornton    5206
# 10       Alan Trammell    4631
# 11        Alex Trevino    1876
# 12       Andy VanSlyke    1512
# 13        Alan Wiggins    1941
# 14          Bill Almon    3231
# 16          Buddy Bell    8068
# 17    Buddy Biancalana     479
# 18        Bruce Bochte    5233
# 19         Bruce Bochy     727
# 20         Barry Bonds     413
# 21       Bobby Bonilla     426
# 23          Bob Brenly    1924
# 24        Bill Buckner    8424
# 25        Brett Butler    2695
# 26         Bob Dernier    1931
# 27             Bo Diaz    2331
# 28          Bill Doran    2308
# 29       Brian Downing    5201
# 30         Bobby Grich    6890
# 31       Billy Hatcher     591
# 32          Bob Horner    3571
# 33        Brook Jacoby    1646
# 34         Bob Kearney    1309
# ...

# %% [markdown]
# ### 3. Find out the name of the player who has hit max home runs

# %%
df.sort_values(by="CHmRun",ascending=False) \
    .head(1)
# Out:
#                Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 249  Reggie Jackson    419   101     18    65   58     92     20    9528
#
#      CHits  CHmRun  CRuns  CRBI  CWalks League Division  PutOuts  Assists  \
# 249   2510     548   1509  1659    1342      A        W        0        0
#
#      Errors  Salary NewLeague
# 249       0   487.5         A

# %% [markdown]
# ### 4. Find out league wise total number of players

# %%
df["League"].value_counts()
# Out:
# League
# A    175
# N    147
# Name: count, dtype: int64

# %% [markdown]
# ### 5. Find out division wise total amount of salary invested

# %%
df["Division"].unique()
# Out:
# array(['E', 'W'], dtype=object)

# %%
df.groupby(by="Division") \
    .agg({"Salary":"sum"})
# Out:
#              Salary
# Division
# E         80531.006
# W         60417.501

# %% [markdown]
# ### 6. Find out five most senior players

# %%
df.sort_values(by = "Years", ascending = False) \
    .head(5)
# Out:
#                Name  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 236       Pete Rose    237    52      0    15   25     30     24   14053
# 302      Tony Perez    200    51      2    14   29     25     23    9778
# 121   Graig Nettles    354    77     16    36   55     41     20    8716
# 249  Reggie Jackson    419   101     18    65   58     92     20    9528
# 306     Ted Simmons    127    32      4    14   25     12     19    8396
#
#      CHits  CHmRun  CRuns  CRBI  CWalks League Division  PutOuts  Assists  \
# 236   4256     160   2165  1314    1566      N        W      523       43
# 302   2732     379   1272  1652     925      N        W      398       29
# 121   2172     384   1172  1267    1057      N        W       83      174
# 249   2510     548   1509  1659    1342      A        W        0        0
# 306   2402     242   1048  1348     819      N        W      167       18
#
#      Errors  Salary NewLeague
# 236       6   750.0         N
# ...

# %% [markdown]
# # B. CARS DATASET

# %%
path2 = r"C:\Users\ASUS\Documents\basic_pythonfiles\project 1\Cars93 (1).csv"
path2
# Out:
# 'C:\\Users\\ASUS\\Documents\\basic_pythonfiles\\project 1\\Cars93 (1).csv'

# %%
df2 = pd.read_csv(path2 ,na_values=["" , "NA"], keep_default_na=False)
df2
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 0    1          Acura         Integra    Small       12.9   15.9       18.8
# 1    2          Acura          Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi              90  Compact       25.9   29.1       32.3
# 3    4           Audi             100  Midsize       30.8   37.7       44.6
# 4    5            BMW            535i  Midsize       23.7   30.0       36.2
# 5    6          Buick         Century  Midsize       14.2   15.7       17.3
# 6    7          Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8          Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9          Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11       Cadillac         Seville  Midsize       37.5   40.1       42.7
# ...

# %% [markdown]
# ### 1. Find out car having highest Mileage in city

# %%
df2.nlargest(n=1,columns = "MPG.city")
# Out:
#     id Manufacturer  Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo  Metro  Small        6.7    8.4       10.0        46
#
#     MPG.highway AirBags DriveTrain Cylinders  EngineSize  Horsepower   RPM  \
# 38           50    None      Front         3         1.0          55  5700
#
#     Rev.per.mile Man.trans.avail  Fuel.tank.capacity  Passengers  Length  \
# 38          3755             Yes                10.6           4     151
#
#     Wheelbase  Width  Turn.circle  Rear.seat.room  Luggage.room  Weight  \
# 38         93     63           34            27.5          10.0    1695
#
#      Origin       Make
# 38  non-USA  Geo Metro

# %% [markdown]
# ### 2. Find out Models of cars which are having Price between 17 and 25

# %%
df2.query("Price > 17 and Price <= 25")
# Out:
#     id Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 6    7        Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8        Buick      Roadmaster    Large       22.6   23.7       24.9
# 17  18    Chevrolet         Caprice    Large       18.0   18.8       19.6
# 19  20     Chrylser        Concorde    Large       18.4   18.4       18.4
# 25  26        Dodge         Caravan      Van       13.6   19.0       24.4
# 29  30        Eagle          Vision    Large       17.5   19.3       21.2
# 35  36         Ford        Aerostar      Van       14.5   19.9       25.3
# 36  37         Ford          Taurus  Midsize       15.6   20.2       24.8
# 37  38         Ford  Crown_Victoria    Large       20.1   20.9       21.7
# 40  41        Honda         Prelude   Sporty       17.0   19.8       22.7
# 42  43        Honda          Accord  Compact       13.8   17.5       21.2
# 55  56        Mazda             MPV      Van       16.6   19.1       21.7
# ...

# %% [markdown]
# ### 3. Find out top 7 most fuel economic cars for highway

# %%
df2.nlargest(n=7 , columns = "MPG.highway")
# Out:
#     id Manufacturer   Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo   Metro  Small        6.7    8.4       10.0        46
# 41  42        Honda   Civic  Small        8.4   12.1       15.8        42
# 82  83       Suzuki   Swift  Small        7.3    8.6       10.0        39
# 72  73      Pontiac  LeMans  Small        8.2    9.0        9.9        31
# 78  79       Saturn      SL  Small        9.2   11.1       12.9        28
# 52  53        Mazda     323  Small        7.4    8.3        9.1        29
# 79  80       Subaru   Justy  Small        7.3    8.4        9.5        33
#
#     MPG.highway      AirBags DriveTrain Cylinders  EngineSize  Horsepower  \
# 38           50         None      Front         3         1.0          55
# 41           46  Driver only      Front         4         1.5         102
# 82           43         None      Front         3         1.3          70
# 72           41         None      Front         4         1.6          74
# ...

# %% [markdown]
# ###  4. Find out Models of cars having no AirBags and which are of compact type whose price is below 20.

# %%
q = (
    "AirBags == 'None' and "
    "Type == 'Compact' and "
    "Price < 20"
)
print(q)
# Out:
# AirBags == 'None' and Type == 'Compact' and Price < 20

# %%
df2.query(q)
# Out:
#     id Manufacturer     Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 11  12    Chevrolet  Cavalier  Compact        8.5   13.4       18.3        25
# 32  33         Ford     Tempo  Compact       10.4   11.3       12.2        22
# 67  68   Oldsmobile   Achieva  Compact       13.0   13.5       14.0        24
# 73  74      Pontiac   Sunbird  Compact        9.4   11.1       12.8        23
#
#     MPG.highway AirBags DriveTrain Cylinders  EngineSize  Horsepower   RPM  \
# 11           36    None      Front         4         2.2         110  5200
# 32           27    None      Front         4         2.3          96  4200
# 67           31    None      Front         4         2.3         155  6000
# 73           31    None      Front         4         2.0         110  5200
#
#     Rev.per.mile Man.trans.avail  Fuel.tank.capacity  Passengers  Length  \
# 11          2380             Yes                15.2           5     182
# ...

# %% [markdown]
# ### 5. Find out top 7 most fuel economic cars for city, show results in sorted manner based on Horsepower.

# %%
df2.nlargest(n=7,columns="MPG.city") \
    .sort_values(by="Horsepower")
# Out:
#     id Manufacturer    Model   Type  Min.Price  Price  Max.Price  MPG.city  \
# 38  39          Geo    Metro  Small        6.7    8.4       10.0        46
# 30  31         Ford  Festiva  Small        6.9    7.4        7.9        31
# 82  83       Suzuki    Swift  Small        7.3    8.6       10.0        39
# 79  80       Subaru    Justy  Small        7.3    8.4        9.5        33
# 72  73      Pontiac   LeMans  Small        8.2    9.0        9.9        31
# 83  84       Toyota   Tercel  Small        7.8    9.8       11.8        32
# 41  42        Honda    Civic  Small        8.4   12.1       15.8        42
#
#     MPG.highway      AirBags DriveTrain Cylinders  EngineSize  Horsepower  \
# 38           50         None      Front         3         1.0          55
# 30           33         None      Front         4         1.3          63
# 82           43         None      Front         3         1.3          70
# ...

# %% [markdown]
# ### 6. Find out Cars having mileage of more than 15 miles in city

# %%
df2.query("`MPG.city` > 15")
# Out:
#     id   Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 0    1          Acura         Integra    Small       12.9   15.9       18.8
# 1    2          Acura          Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi              90  Compact       25.9   29.1       32.3
# 3    4           Audi             100  Midsize       30.8   37.7       44.6
# 4    5            BMW            535i  Midsize       23.7   30.0       36.2
# 5    6          Buick         Century  Midsize       14.2   15.7       17.3
# 6    7          Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8          Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9          Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11       Cadillac         Seville  Midsize       37.5   40.1       42.7
# ...

# %% [markdown]
# ### 7. Find out Cars with US based origin¶

# %%
df2.query("Origin == 'USA' ")
# Out:
#     id Manufacturer           Model     Type  Min.Price  Price  Max.Price  \
# 5    6        Buick         Century  Midsize       14.2   15.7       17.3
# 6    7        Buick         LeSabre    Large       19.9   20.8       21.7
# 7    8        Buick      Roadmaster    Large       22.6   23.7       24.9
# 8    9        Buick         Riviera  Midsize       26.3   26.3       26.3
# 9   10     Cadillac         DeVille    Large       33.0   34.7       36.3
# 10  11     Cadillac         Seville  Midsize       37.5   40.1       42.7
# 11  12    Chevrolet        Cavalier  Compact        8.5   13.4       18.3
# 12  13    Chevrolet         Corsica  Compact       11.4   11.4       11.4
# 13  14    Chevrolet          Camaro   Sporty       13.4   15.1       16.8
# 14  15    Chevrolet          Lumina  Midsize       13.4   15.9       18.4
# 15  16    Chevrolet      Lumina_APV      Van       14.7   16.3       18.0
# 16  17    Chevrolet           Astro      Van       14.7   16.6       18.6
# ...

# %% [markdown]
# ### 8. Find out Cars with no airbags and which are compact in type, from the output retrieve only Model, Mileage in city, Type, Airbags

# %%
q =(
    "AirBags == 'None' and "
    "Type == 'Compact'"
)
print(q)
# Out:
# AirBags == 'None' and Type == 'Compact'

# %%
df2.query(q) \
    [["Model","MPG.city","Type","AirBags"]]
# Out:
#        Model  MPG.city     Type AirBags
# 11  Cavalier        25  Compact    None
# 32     Tempo        22  Compact    None
# 67   Achieva        24  Compact    None
# 73   Sunbird        23  Compact    None
# 89    Passat        21  Compact    None

# %% [markdown]
# ### 9. Find out cars with Mileage in city more than 15 which are compact in type.

# %%
q5 = (
    "`MPG.city` > 15 and "
    "Type == 'Compact'"
)
print(q)
# Out:
# 'MPG.city' > 15 and Type == 'Compact'

# %%
df2.query(q5)
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 2    3           Audi        90  Compact       25.9   29.1       32.3
# 11  12      Chevrolet  Cavalier  Compact        8.5   13.4       18.3
# 12  13      Chevrolet   Corsica  Compact       11.4   11.4       11.4
# 20  21       Chrysler   LeBaron  Compact       14.5   15.8       17.1
# 24  25          Dodge    Spirit  Compact       11.9   13.3       14.7
# 32  33           Ford     Tempo  Compact       10.4   11.3       12.2
# 42  43          Honda    Accord  Compact       13.8   17.5       21.2
# 54  55          Mazda       626  Compact       14.3   16.5       18.7
# 57  58  Mercedes-Benz      190E  Compact       29.0   31.9       34.9
# 64  65         Nissan    Altima  Compact       13.0   15.7       18.3
# 67  68     Oldsmobile   Achieva  Compact       13.0   13.5       14.0
# 73  74        Pontiac   Sunbird  Compact        9.4   11.1       12.8
# ...
